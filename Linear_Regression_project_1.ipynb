# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Power Plant Data.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-9-4110682326.py in <cell line: 0>()
# ----> 1 df = pd.read_csv('Power Plant Data.csv')
#
# /usr/local/lib/python3.11/dist-packages/pandas/io/parsers/readers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1024     kwds.update(kwds_defaults)
# ...

# %%
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-6-1396537375.py in <cell line: 0>()
# ----> 1 df
#
# NameError: name 'df' is not defined

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
sns.heatmap(df, cmap='viridis')
# Out:
# <Axes: >

# %%
sns.boxplot(df)
# Out:
# <Axes: >

# %%
sns.distplot(df)
# Out:
# /tmp/ipython-input-83-107776459.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df)
# <Axes: ylabel='Density'>

# %%
df = df.rename(columns = {'AT' : 'ambient_temp', 'V' : 'exhaust_vac', 'AP' : 'ambient_pre', 'RH' : 'retative_humidity'})
df = df.rename(columns= {'PE' : 'electrical_output'})

# %%
df.head()
# Out:
#    ambient_temp  exhaust_vac  ambient_pre  retative_humidity      PE
# 0         14.96        41.76      1024.07              73.17  463.26
# 1         25.18        62.96      1020.04              59.08  444.37
# 2          5.11        39.40      1012.16              92.14  488.56
# 3         20.86        57.32      1010.24              76.64  446.48
# 4         10.82        37.50      1009.23              96.62  473.90

# %%
plt.plot(df)

# %%
plt.scatter(df['ambient_temp'], df['electrical_output'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.11/dist-packages/pandas/core/indexes/base.py in get_loc(self, key)
#    3804         try:
# -> 3805             return self._engine.get_loc(casted_key)
#    3806         except KeyError as err:
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'electrical_output'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-94-833757225.py in <cell line: 0>()
# ----> 1 plt.scatter(df['ambient_temp'], df['electrical_output'])
# ...

# %%
plt.scatter(df['exhaust_vac'], df['electrical_output'])

# %%
sns.boxenplot(df)
# Out:
# <Axes: >

# %%
sns.jointplot(df)

# %%
df.head()
# Out:
#    ambient_temp  exhaust_vac  ambient_pre  retative_humidity      PE
# 0         14.96        41.76      1024.07              73.17  463.26
# 2          5.11        39.40      1012.16              92.14  488.56
# 3         20.86        57.32      1010.24              76.64  446.48
# 4         10.82        37.50      1009.23              96.62  473.90
# 5         26.27        59.44      1012.23              58.77  443.67

# %%
df = df.drop(1 ,axis = 0)

# %%
x =  df.drop(['electrical_output'], axis=1).values
print(x)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipython-input-98-4090174773.py in <cell line: 0>()
# ----> 1 x =  df.drop(['electrical_output'], axis=1).values
#       2 print(x)
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5579                 weight  1.0     0.8
#    5580         """
# -> 5581         return super().drop(
#    5582             labels=labels,
#    5583             axis=axis,
#
# /usr/local/lib/python3.11/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4786         for axis, labels in axes.items():
#    4787             if labels is not None:
# -> 4788                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4789
#    4790         if inplace:
#
# ...

# %%
y = df.drop(['ambient_temp', 'exhaust_vac', 'ambient_pre', 'retative_humidity'], axis=1).values
print(y)
# Out:
# [[463.26]
#  [488.56]
#  [446.48]
#  ...
#  [429.57]
#  [435.74]
#  [453.28]]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train, y_test = train_test_split(x, y, test_size= 0.25, random_state=10)

# %%
from sklearn.linear_model import LinearRegression

# %%
ml = LinearRegression()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3-3643277589.py in <cell line: 0>()
# ----> 1 ml = LinearRegression()
#
# NameError: name 'LinearRegression' is not defined

# %%
ml.fit(x_test, y_test)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-2-1582775607.py in <cell line: 0>()
# ----> 1 ml.fit(x_test, y_test)
#
# NameError: name 'ml' is not defined

# %%
x_pred = ml.predict(x_train)
print(x_pred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-1-1841876150.py in <cell line: 0>()
# ----> 1 x_pred = ml.predict(x_train)
#       2 print(x_pred)
#
# NameError: name 'ml' is not defined

# %%
# Hexagonal Binning Plot
sns.jointplot(x='ambient_temp', y='electrical_output', data=df, kind='hex')
plt.suptitle('Hexagonal Binning Plot of Ambient Temperature vs Electrical Output', y=1.02)
plt.show()

# %%
sns.jointplot(x='exhaust_vac', y='electrical_output', data=df, kind='hex')

# %%
sns.jointplot(x='ambient_pre', y='electrical_output', data=df, kind='hex')

# %%
sns.jointplot(x='retative_humidity', y='electrical_output', data=df, kind='hex')

# %%
# Contour Plot
sns.jointplot(x='ambient_temp', y='electrical_output', data=df, kind='kde')
plt.suptitle('Contour Plot of Ambient Temperature vs Electrical Output', y=1.02)
plt.show()

# %%
# Heatmap of the correlation matrix
corrv = df.corr()
sns.heatmap(corrv, annot=True, cmap='Blues')
plt.title('Correlation Heatmap')
plt.show()

# %%
df.head()
# Out:
#    ambient_temp  exhaust_vac  ambient_pre  retative_humidity  \
# 0         14.96        41.76      1024.07              73.17
# 2          5.11        39.40      1012.16              92.14
# 3         20.86        57.32      1010.24              76.64
# 4         10.82        37.50      1009.23              96.62
# 5         26.27        59.44      1012.23              58.77
#
#    electrical_output
# 0             463.26
# 2             488.56
# 3             446.48
# 4             473.90
# 5             443.67

# %%
# Violin Plot for all numerical columns
plt.figure(figsize=(10, 6))
sns.violinplot(data=df[['ambient_temp', 'exhaust_vac', 'ambient_pre', 'retative_humidity', 'electrical_output']])
plt.title('Violin Plot of Numerical Features')
plt.ylabel('Value')
plt.show()
